# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import qgrid
qgrid.nbinstall(overwrite=True)

# %%
train_predict_file = 'training_set_values.csv'
train_target_file = 'training_set_labels.csv'

test_predict_file = 'test_set_values.csv'

# %%
predictors = pd.read_csv(train_predict_file, index_col=0)
qgrid.show_grid(predictors, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %%
predictors.shape
# Out:
# (59400, 39)

# %%
test = pd.read_csv(test_predict_file, index_col=0)
test.shape
# Out:
# (14850, 39)

# %%
predictors.columns
# Out:
# Index(['amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer',
#        'longitude', 'latitude', 'wpt_name', 'num_private', 'basin',
#        'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward',
#        'population', 'public_meeting', 'recorded_by', 'scheme_management',
#        'scheme_name', 'permit', 'construction_year', 'extraction_type',
#        'extraction_type_group', 'extraction_type_class', 'management',
#        'management_group', 'payment', 'payment_type', 'water_quality',
#        'quality_group', 'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group'],
#       dtype='object')

# %%
print(min(predictors['date_recorded']), max(predictors['date_recorded']))
# Out:
# 2002-10-14 2013-12-03

# %%
sns.distplot(predictors.amount_tsh);
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.countplot(predictors.funder)

# %%
sns.countplot(predictors.installer)

# %%
sns.countplot(predictors.basin)

# %%
# sns.countplot(predictors.subvillage) # Takes too long

# %%
sns.countplot(predictors.region)

# %%
sns.countplot(predictors.region_code)

# %%
sns.countplot(predictors.district_code)

# %%
sns.countplot(predictors.lga)

# %%
sns.countplot(predictors.ward)

# %%
sns.distplot(predictors.population)
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.countplot(predictors.public_meeting)

# %%
sns.countplot(predictors.recorded_by)

# %%
sns.countplot(predictors.scheme_management)

# %%
sns.countplot(predictors.scheme_name)

# %%
sns.countplot(predictors.permit)

# %%
sns.countplot(predictors.construction_year)

# %%
sns.countplot(predictors.extraction_type)

# %%
sns.countplot(predictors.extraction_type_group)

# %%
sns.countplot(predictors.extraction_type_class)

# %%
sns.countplot(predictors.management)

# %%
sns.countplot(predictors.management_group)

# %%
sns.countplot(predictors.payment)

# %%
sns.countplot(predictors.payment_type)

# %%
sns.countplot(predictors.water_quality)

# %%
sns.countplot(predictors.quality_group);

# %%
sns.countplot(predictors.quantity)

# %%
sns.countplot(predictors.quantity_group)

# %%
sns.countplot(predictors.source);

# %%
sns.countplot(predictors.source_type);

# %%
sns.countplot(predictors.source_class);

# %%
sns.countplot(predictors.waterpoint_type);

# %%
sns.countplot(predictors.waterpoint_type_group);
